# %% [markdown]
# Understanding the Dataset
#
# Patient File No. : This is the report number which has data for a particular patient
#
# PCOS : Polycystic ovary syndrome (PCOS) is a hormonal disorder common among women of reproductive age, we would like to determine whether the patient has this syndrome or not
#
# Age (yrs) : Age of patient in years
#
# Weight (Kg) : Weight of patient in kg
#
# Height(Cm) : Height of patient in centimeter
#
# BMI : Body mass index of the patient
#
# Blood Group : Blood Group of the patient A+ = 11, A- = 12, B+ = 13, B- = 14, O+ =15, O- = 16, AB+ =17, AB- = 18 (total 8 blood groups)
#
# Pulse rate(bpm) : It is the heart rate of patient in beats per minute. Resting heart rate for adults ranges from 60 to 100 beats per minute
#
# RR (breaths/min) : It is the respiration rate. Normal respiration rates for an adult person at rest range from 12 to 16 breaths per minute.
#
# Hb(g/dl) : Hemoglobin levels in gram per deciliter. For women, a normal level ranges between 12.3 gm/dL and 15.3 gm/dL.
#
# Cycle(R/I) : ....
#
# Cycle length(days) : This represents length of menstrual cycle. The length of the menstrual cycle varies from woman to woman, but the average is to have periods every 28 days.
#
# Marraige Status (Yrs) : Years of marriage
#
# Pregnant(Y/N) : If the patient is pregnant
#
# No. of aborptions : No. of aborptions, if any. There are total 541 values out of which 437 patients never had any abortions.
#
# I beta-HCG(mIU/mL) : this is case 1 of beta hcg
#
# II beta-HCG(mIU/mL) : this is case 2 of beta hcg (please note: An beta hCG level of less than 5 mIU/mL is considered negative for pregnancy, and anything above 25 mIU/mL is considered positive for pregnancy) (also the unit mIU/mL is mili International Units per miliLiter)
#
# FSH(mIU/mL) : Its full form is Follicle-stimulating hormone. During puberty: it ranges from 0.3 to 10.0 mIU/mL (0.3 to 10.0 IU/L) Women who are still menstruating: 4.7 to 21.5 mIU/mL (4.5 to 21.5 IU/L) After menopause: 25.8 to 134.8 mIU/mL (25.8 to 134.8 IU/L)
#
# LH(mIU/mL) : It is Luteinizing Hormone.
#
# FSH/LH : Ratio of FSH and LH
#
# Hip(inch) : Hip size in inches
#
# Waist(inch) : Waist Size in inches
#
# Waist:Hip Ratio : Waist by hip ratio
#
# TSH (mIU/L) : It is thyroid stimulating hormone. Normal values are from 0.4 to 4.0 mIU/L
#
# AMH(ng/mL) : It is Anti-Mullerian Hormone.
#
# PRL(ng/mL) : This represents Prolactin levels.
#
# Vit D3 (ng/mL): Vitamin D levels. Normal vitamin D levels in the blood are 20 ng/ml or above for adults.
#
# PRG(ng/mL): Progesterone levels
#
# RBS(mg/dl): This value is obtained by doing Random Blood Sugar (RBS) Test.
#
# Weight gain(Y/N): Is there been a weight gain
#
# hair growth(Y/N): Is there been a hair growth
#
# Skin darkening (Y/N): Skin darkening issues
#
# Hair loss(Y/N): hair loss issues
#
# Pimples(Y/N): pimples issues
#
# Fast food (Y/N): is fast food part of you diet
#
# Reg.Exercise(Y/N): do you do exercises on a regular basis
#
# BP _Systolic (mmHg): Systolic blood pressure, measures the pressure in your arteries when your heart beats.
#
# BP _Diastolic (mmHg): Diastolic blood pressure, measures the pressure in your arteries when your heart rests between beats.
#
# Follicle No. (L): Follicles number in the left side
#
# Follicle No. (R): Follicles number in the right side
#
# Avg. F size (L) (mm): Average Follicle size in the left side in mm
#
# Avg. F size (R) (mm): Average Follicle size in the right side in mm
#
# Endometrium (mm): Size of Endometrium in mm

# %%
# Phase 1: Data Preparation and Cleaning

import pandas as pd

# Loading the dataset and handling exceptions
#method to load the dataset
file_path = "C:/Users/USER/Downloads/PCOSDATA.csv"


try:
    with open(file_path, 'r') as file:
        data = pd.read_csv(file)


   


except FileNotFoundError:
    print(f"File not found at {file_path}. Please check the file path.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
data.head()
# Out:
#    SI. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1           0          28         44.6        152.0
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#          BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0  19.300000           15                78                22  ...
# 1  24.921163           15                74                20  ...
# 2  25.270891           11                72                18  ...
# 3  29.674945           13                72                20  ...
# 4  20.060954           11                72                18  ...
#
#    Pimples(Y/N)  Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# ...

# %%
data.columns
# Out:
# Index(['SI. No', 'Patient File No.', 'PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)',
#        'Height(Cm) ', 'BMI', 'Blood Group', 'Pulse rate(bpm) ',
#        'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)',
#        'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions',
#        '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)',
#        'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'Waist/Hip Ratio',
#        'TSH(mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)',
#        'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)',
#        'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SI. No                  541 non-null    int64
#  1   Patient File No.        541 non-null    int64
#  2   PCOS (Y/N)              541 non-null    int64
#  3    Age (yrs)              541 non-null    int64
#  4   Weight (Kg)             541 non-null    float64
#  5   Height(Cm)              541 non-null    float64
#  6   BMI                     541 non-null    float64
#  7   Blood Group             541 non-null    int64
#  8   Pulse rate(bpm)         541 non-null    int64
#  9   RR (breaths/min)        541 non-null    int64
#  10  Hb(g/dl)                541 non-null    float64
#  11  Cycle(R/I)              541 non-null    int64
#  12  Cycle length(days)      541 non-null    int64
#  13  Marraige Status (Yrs)   540 non-null    float64
# ...

# %%
data = data.rename(columns=lambda x: x.strip()) 

column_mapping = {
    'Sl. No': 'Sl_No',
    'Weight (Kg)': 'Weight_kg',
    'Patient File No.': 'Patient_File_No',
    'PCOS (Y/N)': 'PCOS',
    'Age (yrs)': 'Age',
    'Height(Cm)': 'Height_Cm',
    'Pulse rate(bpm)': 'Pulse_rate_bpm',
    'RR (breaths/min)': 'RR_breaths/min',
    'Cycle length(days)': 'Cycle_length_days',
    'Marraige Status (Yrs)': 'Marriage_Status_Yrs',
    'Pregnant(Y/N)': 'Pregnant',
    'No. of aborptions': 'No_of_abortions',
    'I   beta-HCG(mIU/mL)': 'I_beta_HCG_mIU/mL',
    'II    beta-HCG(mIU/mL)': 'II_beta_HCG_mIU/mL',
    'FSH(mIU/mL)': 'FSH_mIU/mL',
    'LH(mIU/mL)': 'LH_mIU/mL',
    'FSH/LH': 'FSH/LH',
    'Hip(inch)': 'Hip_inch',
    'Waist(inch)': 'Waist_inch',
    'Waist/Hip Ratio': 'Waist/Hip_Ratio',
    'TSH(mIU/L)': 'TSH_mIU/L',
    'AMH(ng/mL)': 'AMH_ng/mL',
    'PRL(ng/mL)': 'PRL_ng/mL',
    'Vit D3 (ng/mL)': 'Vit_D3_ng/mL',
    'PRG(ng/mL)': 'PRG_ng/mL',
    'RBS(mg/dl)': 'RBS_mg/dl',
    'Weight gain(Y/N)': 'Weight_gain',
    'hair growth(Y/N)': 'Hair_growth',
    'Skin darkening (Y/N)': 'Skin_darkening',
    'Hair loss(Y/N)': 'Hair_loss',
    'Pimples(Y/N)': 'Pimples',
    'Fast food (Y/N)': 'Fast_food',
    'Reg.Exercise(Y/N)': 'Reg_Exercise',
    'BP _Systolic (mmHg)': 'BP_Systolic_mmHg',
    'BP _Diastolic (mmHg)': 'BP_Diastolic_mmHg',
    'Follicle No. (L)': 'Follicle_No_L',
    'Follicle No. (R)': 'Follicle_No_R',
    'Avg. F size (L) (mm)': 'Avg_F_size_L_mm',
    'Avg. F size (R) (mm)': 'Avg_F_size_R_mm',
    'Endometrium (mm)': 'Endometrium_mm',
    'Unnamed: 44': 'Unnamed_44'
}

data = data.rename(columns=column_mapping)

# %%
data.columns
# Out:
# Index(['SI. No', 'Patient_File_No', 'PCOS', 'Age', 'Weight_kg', 'Height_Cm',
#        'BMI', 'Blood Group', 'Pulse_rate_bpm', 'RR_breaths/min', 'Hb(g/dl)',
#        'Cycle(R/I)', 'Cycle_length_days', 'Marriage_Status_Yrs', 'Pregnant',
#        'No_of_abortions', 'I_beta_HCG_mIU/mL', 'II_beta_HCG_mIU/mL',
#        'FSH_mIU/mL', 'LH_mIU/mL', 'FSH/LH', 'Hip_inch', 'Waist_inch',
#        'Waist/Hip_Ratio', 'TSH_mIU/L', 'AMH_ng/mL', 'PRL_ng/mL',
#        'Vit_D3_ng/mL', 'PRG_ng/mL', 'RBS_mg/dl', 'Weight_gain', 'Hair_growth',
#        'Skin_darkening', 'Hair_loss', 'Pimples', 'Fast_food', 'Reg_Exercise',
#        'BP_Systolic_mmHg', 'BP_Diastolic_mmHg', 'Follicle_No_L',
#        'Follicle_No_R', 'Avg_F_size_L_mm', 'Avg_F_size_R_mm',
#        'Endometrium_mm'],
#       dtype='object')

# %%
print(data.shape)
# Out:
# (541, 44)

# %%
data.head(5).transpose()
# Out:
#                               0           1           2           3  \
# SI. No                 1.000000    2.000000    3.000000    4.000000
# Patient_File_No        1.000000    2.000000    3.000000    4.000000
# PCOS                   0.000000    0.000000    1.000000    0.000000
# Age                   28.000000   36.000000   33.000000   37.000000
# Weight_kg             44.600000   65.000000   68.800000   65.000000
# Height_Cm            152.000000  161.500000  165.000000  148.000000
# BMI                   19.300000   24.921163   25.270891   29.674945
# Blood Group           15.000000   15.000000   11.000000   13.000000
# Pulse_rate_bpm        78.000000   74.000000   72.000000   72.000000
# RR_breaths/min        22.000000   20.000000   18.000000   20.000000
# Hb(g/dl)              10.480000   11.700000   11.800000   12.000000
# Cycle(R/I)             2.000000    2.000000    2.000000    2.000000
# Cycle_length_days      5.000000    5.000000    5.000000    5.000000
# ...

# %%
data.isna().sum()
# Out:
# SI. No                 0
# Patient_File_No        0
# PCOS                   0
# Age                    0
# Weight_kg              0
# Height_Cm              0
# BMI                    0
# Blood Group            0
# Pulse_rate_bpm         0
# RR_breaths/min         0
# Hb(g/dl)               0
# Cycle(R/I)             0
# Cycle_length_days      0
# Marriage_Status_Yrs    1
# Pregnant               0
# No_of_abortions        0
# I_beta_HCG_mIU/mL      0
# II_beta_HCG_mIU/mL     0
# FSH_mIU/mL             0
# LH_mIU/mL              0
# FSH/LH                 0
# Hip_inch               0
# Waist_inch             0
# Waist/Hip_Ratio        0
# TSH_mIU/L              0
# AMH_ng/mL              0
# PRL_ng/mL              0
# Vit_D3_ng/mL           0
# PRG_ng/mL              0
# RBS_mg/dl              0
# Weight_gain            0
# Hair_growth            0
# Skin_darkening         0
# Hair_loss              0
# Pimples                0
# Fast_food              1
# Reg_Exercise           0
# ...

# %%
#Fill in the missing Values
marriage_status_mean = data['Marriage_Status_Yrs'].mean()
fast_food_mean = data['Fast_food'].mean()
data.fillna({'Marriage_Status_Yrs': marriage_status_mean}, inplace=True)
data.fillna({'Fast_food': fast_food_mean}, inplace=True)

# %%
# Phase 2: Exploratory Data Analysis
# Summary statistics for numerical features
data.describe().transpose()
# Out:
#                      count        mean          std         min         25%  \
# SI. No               541.0  271.000000   156.317519    1.000000  136.000000
# Patient_File_No      541.0  271.000000   156.317519    1.000000  136.000000
# PCOS                 541.0    0.327172     0.469615    0.000000    0.000000
# Age                  541.0   31.430684     5.411006   20.000000   28.000000
# Weight_kg            541.0   59.637153    11.028287   31.000000   52.000000
# Height_Cm            541.0  156.484835     6.033545  137.000000  152.000000
# BMI                  541.0   24.319353     4.050819   12.417882   21.707923
# Blood Group          541.0   13.802218     1.840812   11.000000   13.000000
# Pulse_rate_bpm       541.0   73.247689     4.430285   13.000000   72.000000
# RR_breaths/min       541.0   19.243993     1.688629   16.000000   18.000000
# Hb(g/dl)             541.0   11.160037     0.866904    8.500000   10.500000
# ...

# %%
#Measuring Skewness
skewness = data.skew()
print("Skewness for each column:")
print(skewness)
# Out:
# Skewness for each column:
# SI. No                  0.000000
# Patient_File_No         0.000000
# PCOS                    0.738773
# Age                     0.354004
# Weight_kg               0.515227
# Height_Cm               0.325193
# BMI                     0.265719
# Blood Group            -0.132627
# Pulse_rate_bpm         -7.948497
# RR_breaths/min          1.234130
# Hb(g/dl)                0.744115
# Cycle(R/I)              0.997662
# Cycle_length_days       0.826791
# Marriage_Status_Yrs     1.143231
# Pregnant                0.492425
# No_of_abortions         2.970831
# I_beta_HCG_mIU/mL       7.523336
# II_beta_HCG_mIU/mL     12.808928
# FSH_mIU/mL             23.244530
# LH_mIU/mL              23.234664
# FSH/LH                 21.463642
# Hip_inch               -0.200873
# Waist_inch              0.194675
# Waist/Hip_Ratio        -0.349283
# TSH_mIU/L               9.790706
# AMH_ng/mL               3.291579
# PRL_ng/mL               2.441412
# ...

# %%
# Visualizing the distribution of the target variable
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='PCOS', data=data)
plt.title('Distribution of PCOS')
plt.show()

# %%
# Visualizing the correlation matrix
corr_matrix = data.corr()
print("Correlation Matrix:")
plt.subplots(figsize=(30,10))
sns.heatmap(corr_matrix,cmap="Set3", annot = True, fmt = ".2f");
plt.title("Correlation Matrix")
plt.show()
# Out:
# Correlation Matrix:

# %%
#Check for outliers
# Boxplot for each feature
plt.figure(figsize=(25, 5))
sns.boxplot(data=data)
plt.title('Boxplot of Features')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualizing the distribution of categorical features
categorical_features = ['Blood Group', 'Pregnant', 'Weight_gain', 'Hair_growth', 'Skin_darkening', 'Hair_loss', 'Pimples', 'Fast_food', 'Reg_Exercise']
for feature in categorical_features:
    sns.countplot(x=feature, data=data)
    plt.title(f'Distribution of {feature}')
    plt.show()

# %%
# Visualizing the distribution of numerical features
numerical_features = ['Age', 'Weight_kg', 'Height_Cm', 'BMI', 'Pulse_rate_bpm', 'RR_breaths/min', 'Cycle_length_days', 'Marriage_Status_Yrs', 'Hip_inch', 'Waist_inch', 'Waist/Hip_Ratio', 'BP_Systolic_mmHg', 'BP_Diastolic_mmHg']
for feature in numerical_features:
    sns.histplot(data=data, x=feature, kde=True)
    plt.title(f'Distribution of {feature}')
    plt.show()

# %%
#Phase 3: Predictive Modelling Development
X = data.drop(["PCOS", "SI. No", "Patient_File_No"], axis=1)
y = data["PCOS"]

# %%
X.columns
# Out:
# Index(['Age', 'Weight_kg', 'Height_Cm', 'BMI', 'Blood Group', 'Pulse_rate_bpm',
#        'RR_breaths/min', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle_length_days',
#        'Marriage_Status_Yrs', 'Pregnant', 'No_of_abortions',
#        'I_beta_HCG_mIU/mL', 'II_beta_HCG_mIU/mL', 'FSH_mIU/mL', 'LH_mIU/mL',
#        'FSH/LH', 'Hip_inch', 'Waist_inch', 'Waist/Hip_Ratio', 'TSH_mIU/L',
#        'AMH_ng/mL', 'PRL_ng/mL', 'Vit_D3_ng/mL', 'PRG_ng/mL', 'RBS_mg/dl',
#        'Weight_gain', 'Hair_growth', 'Skin_darkening', 'Hair_loss', 'Pimples',
#        'Fast_food', 'Reg_Exercise', 'BP_Systolic_mmHg', 'BP_Diastolic_mmHg',
#        'Follicle_No_L', 'Follicle_No_R', 'Avg_F_size_L_mm', 'Avg_F_size_R_mm',
#        'Endometrium_mm'],
#       dtype='object')

# %%
import numpy as np
from sklearn.model_selection import train_test_split

#Split the dataset into features (X) and the target variable (y).
#Split the data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#Training several machine learning models on the training data.
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# Assuming X and y are your features and labels for a regression problem
# Instantiate a RandomForestRegressor
random_forest_regressor = RandomForestRegressor(random_state=42)

# Fit the regressor on the entire dataset
random_forest_regressor.fit(X, y)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Get feature importances from the trained model
feature_importances = random_forest_regressor.feature_importances_

# Create a DataFrame to display feature names and their importance scores
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display or visualize the feature importance
print(100*feature_importance_df)

# Plot the feature importance
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Importance')
plt.title('Feature Importance for Random Forest')
plt.show()
# Out:
#                                               Feature  Importance
# 37  Follicle_No_RFollicle_No_RFollicle_No_RFollicl...   44.453619
# 28  Hair_growthHair_growthHair_growthHair_growthHa...    6.089747
# 36  Follicle_No_LFollicle_No_LFollicle_No_LFollicl...    6.084136
# 27  Weight_gainWeight_gainWeight_gainWeight_gainWe...    3.677277
# 17  FSH/LHFSH/LHFSH/LHFSH/LHFSH/LHFSH/LHFSH/LHFSH/...    2.826055
# 22  AMH_ng/mLAMH_ng/mLAMH_ng/mLAMH_ng/mLAMH_ng/mLA...    2.361086
# 32  Fast_foodFast_foodFast_foodFast_foodFast_foodF...    1.868552
# 21  TSH_mIU/LTSH_mIU/LTSH_mIU/LTSH_mIU/LTSH_mIU/LT...    1.778738
# 29  Skin_darkeningSkin_darkeningSkin_darkeningSkin...    1.734869
# 39  Avg_F_size_R_mmAvg_F_size_R_mmAvg_F_size_R_mmA...    1.604438
# 40  Endometrium_mmEndometrium_mmEndometrium_mmEndo...    1.548718
# 16  LH_mIU/mLLH_mIU/mLLH_mIU/mLLH_mIU/mLLH_mIU/mLL...    1.532625
# 3   BMIBMIBMIBMIBMIBMIBMIBMIBMIBMIBMIBMIBMIBMIBMIB...    1.525717
# ...

# %%
rf_y_pred = rf_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, roc_auc_score, roc_curve, precision_recall_curve, auc
from sklearn import metrics

# %%
# Evaluate Random Forest Classifier
rf_accuracy = accuracy_score(y_test, rf_y_pred)

print("\nRandom Forest Classifier:")
rf_accuracy = metrics.accuracy_score(y_test, rf_y_pred)
rf_precision = metrics.precision_score(y_test, rf_y_pred)
rf_recall = metrics.recall_score(y_test, rf_y_pred)
rf_f1 = metrics.f1_score(y_test, rf_y_pred)

print(f"Random Forest Accuracy: {rf_accuracy * 100:.2f}%")
print(f"Random Forest Precision: {rf_precision * 100:.2f}%")
print(f"Random Forest Recall: {rf_recall * 100:.2f}%")
print(f"Random Forest F1 Score: {rf_f1 * 100:.2f}%")
print(classification_report(y_test, rf_y_pred))
# Out:
# Random Forest Classifier:
# Random Forest Accuracy: 88.34%
# Random Forest Precision: 90.48%
# Random Forest Recall: 71.70%
# Random Forest F1 Score: 80.00%
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92       110
#            1       0.90      0.72      0.80        53
#
#     accuracy                           0.88       163
#    macro avg       0.89      0.84      0.86       163
# weighted avg       0.89      0.88      0.88       163

# %%
# Instantiate an SVM model
svm_model = SVC(kernel='linear', probability=True, random_state=42)

# Fit the model on the training data
svm_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True, random_state=42)

# %%
# Get the coefficients (weights) and intercept from the trained model
coefficients = svm_model.coef_.flatten()
intercept = svm_model.intercept_

# Create a DataFrame to display feature names and their coefficients
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Coefficient': coefficients})

# Sort the DataFrame by coefficients in descending order
feature_importance_df = feature_importance_df.reindex(feature_importance_df['Coefficient'].abs().sort_values(ascending=False).index)

# Display or visualize the feature importance
print(100*feature_importance_df)

# Plot the feature importance
plt.figure(figsize=(15, 10))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Coefficient'])
plt.xlabel('Coefficient')
plt.title('Feature Importance for SVM')
plt.show()
# Out:
#                                               Feature  Coefficient
# 27  Weight_gainWeight_gainWeight_gainWeight_gainWe...   115.579651
# 28  Hair_growthHair_growthHair_growthHair_growthHa...    97.909804
# 8   Cycle(R/I)Cycle(R/I)Cycle(R/I)Cycle(R/I)Cycle(...    77.664797
# 31  PimplesPimplesPimplesPimplesPimplesPimplesPimp...    77.074775
# 29  Skin_darkeningSkin_darkeningSkin_darkeningSkin...    58.855204
# 11  PregnantPregnantPregnantPregnantPregnantPregna...   -57.729831
# 32  Fast_foodFast_foodFast_foodFast_foodFast_foodF...    48.235858
# 33  Reg_ExerciseReg_ExerciseReg_ExerciseReg_Exerci...    45.623428
# 37  Follicle_No_RFollicle_No_RFollicle_No_RFollicl...    40.137983
# 3   BMIBMIBMIBMIBMIBMIBMIBMIBMIBMIBMIBMIBMIBMIBMIB...   -32.680226
# 30  Hair_lossHair_lossHair_lossHair_lossHair_lossH...    31.819745
# 36  Follicle_No_LFollicle_No_LFollicle_No_LFollicl...    18.671436
# 40  Endometrium_mmEndometrium_mmEndometrium_mmEndo...   -16.289683
# ...

# %%
# Evaluate SVM Classifier
svm_y_pred = svm_model.predict(X_test)
svm_accuracy = accuracy_score(y_test, svm_y_pred)

print("\nSupport Vector Machine (SVM) Classifier:")
svm_accuracy = metrics.accuracy_score(y_test, svm_y_pred)
svm_precision = metrics.precision_score(y_test, svm_y_pred)
svm_recall = metrics.recall_score(y_test, svm_y_pred)
svm_f1 = metrics.f1_score(y_test, svm_y_pred)

print(f"SVM Accuracy: {svm_accuracy * 100:.2f}%")
print(f"SVM Precision: {svm_precision * 100:.2f}%")
print(f"SVM Recall: {svm_recall * 100:.2f}%")
print(f"SVM F1 Score: {svm_f1 * 100:.2f}%")
print(classification_report(y_test, svm_y_pred))
# Out:
# Support Vector Machine (SVM) Classifier:
# SVM Accuracy: 84.66%
# SVM Precision: 78.00%
# SVM Recall: 73.58%
# SVM F1 Score: 75.73%
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       110
#            1       0.78      0.74      0.76        53
#
#     accuracy                           0.85       163
#    macro avg       0.83      0.82      0.82       163
# weighted avg       0.84      0.85      0.85       163

# %%
# Instantiate a Logistic Regression model
lr_model = LogisticRegression(random_state=42)

# Fit the model on the training data
lr_model.fit(X_train, y_train)
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
# Get coefficients from the trained model
coefficients = lr_model.coef_[0]

# Create a DataFrame to display feature names and their coefficients
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Coefficient': coefficients})

# Sort the DataFrame by coefficients in descending order
feature_importance_df = feature_importance_df.reindex(feature_importance_df['Coefficient'].abs().sort_values(ascending=False).index)

# Display or visualize the feature importance
print(100*feature_importance_df)

# Plot the feature importance
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Coefficient'])
plt.xlabel('Coefficient')
plt.title('Feature Importance for Logistic Regression')
plt.show()
# Out:
#                                               Feature  Coefficient
# 37  Follicle_No_RFollicle_No_RFollicle_No_RFollicl...    30.166316
# 36  Follicle_No_LFollicle_No_LFollicle_No_LFollicl...    24.307997
# 16  LH_mIU/mLLH_mIU/mLLH_mIU/mLLH_mIU/mLLH_mIU/mLL...    22.173050
# 15  FSH_mIU/mLFSH_mIU/mLFSH_mIU/mLFSH_mIU/mLFSH_mI...   -10.015691
# 22  AMH_ng/mLAMH_ng/mLAMH_ng/mLAMH_ng/mLAMH_ng/mLA...     6.712434
# 10  Marriage_Status_YrsMarriage_Status_YrsMarriage...    -6.431383
# 25  PRG_ng/mLPRG_ng/mLPRG_ng/mLPRG_ng/mLPRG_ng/mLP...    -5.793992
# 0   AgeAgeAgeAgeAgeAgeAgeAgeAgeAgeAgeAgeAgeAgeAgeA...    -5.125627
# 8   Cycle(R/I)Cycle(R/I)Cycle(R/I)Cycle(R/I)Cycle(...     4.444237
# 9   Cycle_length_daysCycle_length_daysCycle_length...    -4.428628
# 1   Weight_kgWeight_kgWeight_kgWeight_kgWeight_kgW...     4.273544
# 2   Height_CmHeight_CmHeight_CmHeight_CmHeight_CmH...    -4.240215
# 21  TSH_mIU/LTSH_mIU/LTSH_mIU/LTSH_mIU/LTSH_mIU/LT...    -3.936727
# ...

# %%
# Evaluate LR Classifier
lr_y_pred = lr_model.predict(X_test)
lr_accuracy = accuracy_score(y_test, lr_y_pred)


print("\nLogistic Regression (LR) Classifier:")
lr_accuracy = metrics.accuracy_score(y_test, lr_y_pred)
lr_precision = metrics.precision_score(y_test, lr_y_pred)
lr_recall = metrics.recall_score(y_test, lr_y_pred)
lr_f1 = metrics.f1_score(y_test, lr_y_pred)

print(f"LR Accuracy: {lr_accuracy * 100:.2f}%")
print(f"LR Precision: {lr_precision * 100:.2f}%")
print(f"LR Recall: {lr_recall * 100:.2f}%")
print(f"LR F1 Score: {lr_f1 * 100:.2f}%")
print(classification_report(y_test, lr_y_pred))
# Out:
# Logistic Regression (LR) Classifier:
# LR Accuracy: 80.37%
# LR Precision: 71.43%
# LR Recall: 66.04%
# LR F1 Score: 68.63%
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86       110
#            1       0.71      0.66      0.69        53
#
#     accuracy                           0.80       163
#    macro avg       0.78      0.77      0.77       163
# weighted avg       0.80      0.80      0.80       163

# %%
# Instantiate a KNN model
knn_model = KNeighborsClassifier(n_neighbors=5)

# Fit the model on the training data
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from collections import Counter

# Get indices of k-neighbors for each sample
_, indices = knn_model.kneighbors(X_train, n_neighbors=5)

# Count the occurrences of each feature among neighbors
feature_counts = Counter(indices.flatten())

# Create lists for feature names and their importance scores
feature_names = list(X_train.columns)
importance_scores = [feature_counts.get(idx, 0) for idx in range(len(feature_names))]

# Ensure the lengths of 'Feature' and 'Importance' arrays are the same
assert len(feature_names) == len(importance_scores), "Arrays must be of the same length"

# Create a DataFrame to display feature names and their importance scores
feature_importance_df_knn = pd.DataFrame({'Feature': feature_names, 'Importance': importance_scores})

# Sort the DataFrame by importance scores in descending order
feature_importance_df_knn = feature_importance_df_knn.sort_values(by='Importance', ascending=False)

# Display or visualize the feature importance for KNN
print(feature_importance_df_knn)

# Plot the feature importance
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df_knn['Feature'], feature_importance_df_knn['Importance'])
plt.xlabel('Importance Score')
plt.title('Feature Importance for KNN')
plt.show()
# Out:
#                 Feature  Importance
# 3                   BMI          12
# 14   II_beta_HCG_mIU/mL          12
# 12      No_of_abortions          11
# 26            RBS_mg/dl          10
# 23            PRL_ng/mL          10
# 31              Pimples           9
# 29       Skin_darkening           9
# 32            Fast_food           8
# 33         Reg_Exercise           8
# 5        Pulse_rate_bpm           8
# 35    BP_Diastolic_mmHg           8
# 10  Marriage_Status_Yrs           8
# 17               FSH/LH           8
# 15           FSH_mIU/mL           8
# 39      Avg_F_size_R_mm           6
# 36        Follicle_No_L           6
# 37        Follicle_No_R           5
# 8            Cycle(R/I)           5
# 4           Blood Group           5
# 13    I_beta_HCG_mIU/mL           4
# 11             Pregnant           4
# 38      Avg_F_size_L_mm           4
# 21            TSH_mIU/L           4
# 22            AMH_ng/mL           4
# 7              Hb(g/dl)           4
# ...

# %%
# Evaluate KNN Classifier
knn_y_pred = knn_model.predict(X_test)
knn_accuracy = accuracy_score(y_test, knn_y_pred)

print("\nK-Nearest Neighbors (KNN) Classifier:")
knn_accuracy = metrics.accuracy_score(y_test, knn_y_pred)
knn_precision = metrics.precision_score(y_test, knn_y_pred)
knn_recall = metrics.recall_score(y_test, knn_y_pred)
knn_f1 = metrics.f1_score(y_test, knn_y_pred)

print(f"KNN Accuracy: {knn_accuracy * 100:.2f}%")
print(f"KNN Precision: {knn_precision * 100:.2f}%")
print(f"KNN Recall: {knn_recall * 100:.2f}%")
print(f"KNN F1 Score: {knn_f1 * 100:.2f}%")
print(classification_report(y_test, knn_y_pred))
# Out:
# K-Nearest Neighbors (KNN) Classifier:
# KNN Accuracy: 66.87%
# KNN Precision: 48.84%
# KNN Recall: 39.62%
# KNN F1 Score: 43.75%
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.77       110
#            1       0.49      0.40      0.44        53
#
#     accuracy                           0.67       163
#    macro avg       0.61      0.60      0.60       163
# weighted avg       0.65      0.67      0.66       163

# %%
def get_scores(model, actual, predicted):
    print(f"Model: {model}")


    accuracy = metrics.accuracy_score(actual, predicted)
    print(f"Accuracy: {accuracy * 100:.2f}%")

    conf_matrix = metrics.confusion_matrix(actual, predicted)
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

# %%
get_scores("Random Forest", y_test, rf_y_pred)
# Out:
# Model: Random Forest
# Accuracy: 88.34%

# %%
get_scores("SVM", y_test, svm_y_pred)
# Out:
# Model: SVM
# Accuracy: 84.66%

# %%
get_scores("LR", y_test, lr_y_pred)
# Out:
# Model: LR
# Accuracy: 80.37%

# %%
get_scores("KNN", y_test, knn_y_pred)
# Out:
# Model: KNN
# Accuracy: 66.87%

# %%
#RANDOM FOREST MODEL
# Collect feature values for new persons
Person_A_features = [36,	74.1,	165,	27.21763085,	15,	78,	28,	11.2,	2,	5,
                     8,	1,	0,	237.97,	1.99,	3.24,	1.07,	3.028037383,	44,	38,
                     0.863636364,	1.6,	6.74,	16.18,	52.4,	0.3,	76,	1,	0,	0,
                     1,	0,	0,	0,	110,	70,	9,	6,	16,	20,	8]

Person_B_features = [25,	74,	152,	32.02908587,	17,	72,	18,	11.7,	4,	2,
                     7,	1,	0, 1214.23,	1214.23,	2,	1.51,	1.324503311,	45,	40,
                     0.888888889,	6.51,	7.94,	22.43,	31.4,	0.3,	125,	1,	1,	1,
                     1,	1,	1,	1,	120,	80,	15,	8,	20,	21,	8]

Person_C_features = [34,	63,	158,	25.23634033,	11,	72,	20,	11.2,	2,	5,
                     12,	1,	0,	610.63,	610.63,	5.34,	0.89,	6,	38,	32,
                     0.842105263,	0.65,	1.89,	11.46,	21.5,	0.98,	100,	0,	1,	0,
                     0, 1,	1,	0,	120,	70,	4,	6,	18,	17,	7.3]

Person_D_features = [29,	61,	151,	26.75321258,	13,	74,	20, 10,	2,	5,
                     9,	0,	0,	15,	1.99,	6.49,	0.99, 6.555555556,	42,	35,	0.833333333,
                     1.66,	2.58,	41.63,	38.44,	1.22,	92, 0,	0,	0,
                     0,	0,	0,	0,	120,	70,	5,	6,	12,	6,	6]

import numpy as np
Person_A_features_array = np.array(Person_A_features)
Person_A_features_reshaped = Person_A_features_array.reshape(1, -1)

Person_B_features_array = np.array(Person_B_features)
Person_B_features_reshaped = Person_B_features_array.reshape(1, -1)

Person_C_features_array = np.array(Person_C_features)
Person_C_features_reshaped = Person_C_features_array.reshape(1, -1)

Person_D_features_array = np.array(Person_D_features)
Person_D_features_reshaped = Person_D_features_array.reshape(1, -1)

# Input preprocessed features to the model and obtain prediction
prediction_rf_A = rf_model.predict(Person_A_features_reshaped)  # Use predict method for classification models

# Input preprocessed features to the model and obtain prediction
prediction_rf_B = rf_model.predict(Person_B_features_reshaped)  # Use predict method for classification models

# Input preprocessed features to the model and obtain prediction
prediction_rf_C = rf_model.predict(Person_C_features_reshaped)  # Use predict method for classification models

# Input preprocessed features to the model and obtain prediction
prediction_rf_D = rf_model.predict(Person_D_features_reshaped)  # Use predict method for classification models

print("RANDOM FOREST PREDICTION")
# Interpret prediction
if prediction_rf_A == 1:
    print("Person A is predicted to have PCOS")
else:
    print("Person A is predicted to be free from PCOS")
    
# Interpret prediction
if prediction_rf_B == 1:
    print("Person B is predicted to have PCOS")
else:
    print("Person B is predicted to be free from PCOS")
    
# Interpret prediction
if prediction_rf_C == 1:
    print("Person C is predicted to have PCOS")
else:
    print("Person C is predicted to be free from PCOS")
    
# Interpret prediction
if prediction_rf_D == 1:
    print("Person D is predicted to have PCOS")
else:
    print("Person D is predicted to be free from PCOS")
# Out:
# RANDOM FOREST PREDICTION
# Person A is predicted to be free from PCOS
# Person B is predicted to have PCOS
# Person C is predicted to have PCOS
# Person D is predicted to be free from PCOS
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ...

# %%
#SUPPORT VECTOR MACHINE MODEL
# Collect feature values for new persons
Person_A_features = [36,	74.1,	165,	27.21763085,	15,	78,	28,	11.2,	2,	5,
                     8,	1,	0,	237.97,	1.99,	3.24,	1.07,	3.028037383,	44,	38,
                     0.863636364,	1.6,	6.74,	16.18,	52.4,	0.3,	76,	1,	0,	0,
                     1,	0,	0,	0,	110,	70,	9,	6,	16,	20,	8]

Person_B_features = [25,	74,	152,	32.02908587,	17,	72,	18,	11.7,	4,	2,
                     7,	1,	0, 1214.23,	1214.23,	2,	1.51,	1.324503311,	45,	40,
                     0.888888889,	6.51,	7.94,	22.43,	31.4,	0.3,	125,	1,	1,	1,
                     1,	1,	1,	1,	120,	80,	15,	8,	20,	21,	8]

Person_C_features = [34,	63,	158,	25.23634033,	11,	72,	20,	11.2,	2,	5,
                     12,	1,	0,	610.63,	610.63,	5.34,	0.89,	6,	38,	32,
                     0.842105263,	0.65,	1.89,	11.46,	21.5,	0.98,	100,	0,	1,	0,
                     0, 1,	1,	0,	120,	70,	4,	6,	18,	17,	7.3]

Person_D_features = [29,	61,	151,	26.75321258,	13,	74,	20, 10,	2,	5,
                     9,	0,	0,	15,	1.99,	6.49,	0.99, 6.555555556,	42,	35,	0.833333333,
                     1.66,	2.58,	41.63,	38.44,	1.22,	92, 0,	0,	0,
                     0,	0,	0,	0,	120,	70,	5,	6,	12,	6,	6]

import numpy as np
Person_A_features_array = np.array(Person_A_features)
Person_A_features_reshaped = Person_A_features_array.reshape(1, -1)

Person_B_features_array = np.array(Person_B_features)
Person_B_features_reshaped = Person_B_features_array.reshape(1, -1)

Person_C_features_array = np.array(Person_C_features)
Person_C_features_reshaped = Person_C_features_array.reshape(1, -1)

Person_D_features_array = np.array(Person_D_features)
Person_D_features_reshaped = Person_D_features_array.reshape(1, -1)

# Input preprocessed features to the model and obtain prediction
prediction_svm_A = svm_model.predict(Person_A_features_reshaped)  # Use predict method for classification models

# Input preprocessed features to the model and obtain prediction
prediction_svm_B = svm_model.predict(Person_B_features_reshaped)  # Use predict method for classification models

# Input preprocessed features to the model and obtain prediction
prediction_svm_C = svm_model.predict(Person_C_features_reshaped)  # Use predict method for classification models

# Input preprocessed features to the model and obtain prediction
prediction_svm_D = svm_model.predict(Person_D_features_reshaped)  # Use predict method for classification models

print("SUPPORT VECTOR MACHINE PREDICTION")
# Interpret prediction
if prediction_svm_A == 1:
    print("Person A is predicted to have PCOS")
else:
    print("Person A is predicted to be free from PCOS")
    
# Interpret prediction
if prediction_svm_B == 1:
    print("Person B is predicted to have PCOS")
else:
    print("Person B is predicted to be free from PCOS")
    
# Interpret prediction
if prediction_svm_C == 1:
    print("Person C is predicted to have PCOS")
else:
    print("Person C is predicted to be free from PCOS")
    
# Interpret prediction
if prediction_svm_D == 1:
    print("Person D is predicted to have PCOS")
else:
    print("Person D is predicted to be free from PCOS")
# Out:
# SUPPORT VECTOR MACHINE PREDICTION
# Person A is predicted to be free from PCOS
# Person B is predicted to have PCOS
# Person C is predicted to be free from PCOS
# Person D is predicted to be free from PCOS
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
# ...

# %%
#LOGISTIC REGRESSION MODEL
# Collect feature values for new persons
Person_A_features = [36,	74.1,	165,	27.21763085,	15,	78,	28,	11.2,	2,	5,
                     8,	1,	0,	237.97,	1.99,	3.24,	1.07,	3.028037383,	44,	38,
                     0.863636364,	1.6,	6.74,	16.18,	52.4,	0.3,	76,	1,	0,	0,
                     1,	0,	0,	0,	110,	70,	9,	6,	16,	20,	8]

Person_B_features = [25,	74,	152,	32.02908587,	17,	72,	18,	11.7,	4,	2,
                     7,	1,	0, 1214.23,	1214.23,	2,	1.51,	1.324503311,	45,	40,
                     0.888888889,	6.51,	7.94,	22.43,	31.4,	0.3,	125,	1,	1,	1,
                     1,	1,	1,	1,	120,	80,	15,	8,	20,	21,	8]

Person_C_features = [34,	63,	158,	25.23634033,	11,	72,	20,	11.2,	2,	5,
                     12,	1,	0,	610.63,	610.63,	5.34,	0.89,	6,	38,	32,
                     0.842105263,	0.65,	1.89,	11.46,	21.5,	0.98,	100,	0,	1,	0,
                     0, 1,	1,	0,	120,	70,	4,	6,	18,	17,	7.3]

Person_D_features = [29,	61,	151,	26.75321258,	13,	74,	20, 10,	2,	5,
                     9,	0,	0,	15,	1.99,	6.49,	0.99, 6.555555556,	42,	35,	0.833333333,
                     1.66,	2.58,	41.63,	38.44,	1.22,	92, 0,	0,	0,
                     0,	0,	0,	0,	120,	70,	5,	6,	12,	6,	6]

import numpy as np
Person_A_features_array = np.array(Person_A_features)
Person_A_features_reshaped = Person_A_features_array.reshape(1, -1)

Person_B_features_array = np.array(Person_B_features)
Person_B_features_reshaped = Person_B_features_array.reshape(1, -1)

Person_C_features_array = np.array(Person_C_features)
Person_C_features_reshaped = Person_C_features_array.reshape(1, -1)

Person_D_features_array = np.array(Person_D_features)
Person_D_features_reshaped = Person_D_features_array.reshape(1, -1)

# Input preprocessed features to the model and obtain prediction
prediction_lr_A = lr_model.predict(Person_A_features_reshaped)  # Use predict method for classification models

# Input preprocessed features to the model and obtain prediction
prediction_lr_B = lr_model.predict(Person_B_features_reshaped)  # Use predict method for classification models

# Input preprocessed features to the model and obtain prediction
prediction_lr_C = lr_model.predict(Person_C_features_reshaped)  # Use predict method for classification models

# Input preprocessed features to the model and obtain prediction
prediction_lr_D = lr_model.predict(Person_D_features_reshaped)  # Use predict method for classification models

print("LOGISTIC REGRESSION PREDICTION")
# Interpret prediction
if prediction_lr_A == 1:
    print("Person A is predicted to have PCOS")
else:
    print("Person A is predicted to be free from PCOS")
    
# Interpret prediction
if prediction_lr_B == 1:
    print("Person B is predicted to have PCOS")
else:
    print("Person B is predicted to be free from PCOS")
    
# Interpret prediction
if prediction_lr_C == 1:
    print("Person C is predicted to have PCOS")
else:
    print("Person C is predicted to be free from PCOS")
    
# Interpret prediction
if prediction_lr_D == 1:
    print("Person D is predicted to have PCOS")
else:
    print("Person D is predicted to be free from PCOS")
# Out:
# LOGISTIC REGRESSION PREDICTION
# Person A is predicted to be free from PCOS
# Person B is predicted to have PCOS
# Person C is predicted to be free from PCOS
# Person D is predicted to be free from PCOS
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ...

# %%
#KNN MODEL
# Collect feature values for new persons
Person_A_features = [36,	74.1,	165,	27.21763085,	15,	78,	28,	11.2,	2,	5,
                     8,	1,	0,	237.97,	1.99,	3.24,	1.07,	3.028037383,	44,	38,
                     0.863636364,	1.6,	6.74,	16.18,	52.4,	0.3,	76,	1,	0,	0,
                     1,	0,	0,	0,	110,	70,	9,	6,	16,	20,	8]

Person_B_features = [25,	74,	152,	32.02908587,	17,	72,	18,	11.7,	4,	2,
                     7,	1,	0, 1214.23,	1214.23,	2,	1.51,	1.324503311,	45,	40,
                     0.888888889,	6.51,	7.94,	22.43,	31.4,	0.3,	125,	1,	1,	1,
                     1,	1,	1,	1,	120,	80,	15,	8,	20,	21,	8]

Person_C_features = [34,	63,	158,	25.23634033,	11,	72,	20,	11.2,	2,	5,
                     12,	1,	0,	610.63,	610.63,	5.34,	0.89,	6,	38,	32,
                     0.842105263,	0.65,	1.89,	11.46,	21.5,	0.98,	100,	0,	1,	0,
                     0, 1,	1,	0,	120,	70,	4,	6,	18,	17,	7.3]

Person_D_features = [29,	61,	151,	26.75321258,	13,	74,	20, 10,	2,	5,
                     9,	0,	0,	15,	1.99,	6.49,	0.99, 6.555555556,	42,	35,	0.833333333,
                     1.66,	2.58,	41.63,	38.44,	1.22,	92, 0,	0,	0,
                     0,	0,	0,	0,	120,	70,	5,	6,	12,	6,	6]
import numpy as np
Person_A_features_array = np.array(Person_A_features)
Person_A_features_reshaped = Person_A_features_array.reshape(1, -1)

Person_B_features_array = np.array(Person_B_features)
Person_B_features_reshaped = Person_B_features_array.reshape(1, -1)

Person_C_features_array = np.array(Person_C_features)
Person_C_features_reshaped = Person_C_features_array.reshape(1, -1)

Person_D_features_array = np.array(Person_D_features)
Person_D_features_reshaped = Person_D_features_array.reshape(1, -1)

# Input preprocessed features to the model and obtain prediction
prediction_knn_A = knn_model.predict(Person_A_features_reshaped)  # Use predict method for classification models

# Input preprocessed features to the model and obtain prediction
prediction_knn_B = knn_model.predict(Person_B_features_reshaped)  # Use predict method for classification models

# Input preprocessed features to the model and obtain prediction
prediction_knn_C = knn_model.predict(Person_C_features_reshaped)  # Use predict method for classification models

# Input preprocessed features to the model and obtain prediction
prediction_knn_D= knn_model.predict(Person_D_features_reshaped)  # Use predict method for classification models

print("KNN PREDICTION")
# Interpret prediction
if prediction_knn_A == 1:
    print("Person A is predicted to have PCOS")
else:
    print("Person A is predicted to be free from PCOS")
    
# Interpret prediction
if prediction_knn_B == 1:
    print("Person B is predicted to have PCOS")
else:
    print("Person B is predicted to be free from PCOS")
    
# Interpret prediction
if prediction_knn_C == 1:
    print("Person C is predicted to have PCOS")
else:
    print("Person C is predicted to be free from PCOS")
    
# Interpret prediction
if prediction_knn_D == 1:
    print("Person D is predicted to have PCOS")
else:
    print("Person D is predicted to be free from PCOS")
# Out:
# KNN PREDICTION
# Person A is predicted to be free from PCOS
# Person B is predicted to have PCOS
# Person C is predicted to be free from PCOS
# Person D is predicted to be free from PCOS
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ...
